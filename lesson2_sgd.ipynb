# %% [markdown]
# <a href="https://colab.research.google.com/github/Brycexxx/fastai/blob/master/lesson2_sgd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from fastai.basics import *
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
n = 200
x = torch.ones(n, 2)

# %%
x[:, 0].uniform_(-2, 2)
x[:5]
# Out:
# tensor([[-1.6515,  1.0000],
#         [-0.6493,  1.0000],
#         [-0.9586,  1.0000],
#         [-0.1175,  1.0000],
#         [ 0.5784,  1.0000]])

# %%
def mse(y_hat, y):
    return ((y_hat - y) ** 2).mean()

# %%
def relu(x):
    return x if x >= 0 else 0

# %%
w = tensor(1.5, 3)
y = x ** 2 @ w + torch.rand(n)

# %%
plt.figure()
plt.scatter(x[:, 0], y);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = tensor(1., 1)
a = nn.Parameter(a)
a
# Out:
# Parameter containing:
# tensor([1., 1.], requires_grad=True)

# %%
def update():
    y_hat = x ** 2 @ a
    loss = mse(y_hat, y)
    if t % 10 == 0: print(loss)
    loss.backward()
    with torch.no_grad():
        a.sub_(1e-1 * a.grad)
        a.grad.zero_()

# %%
for t in range(200): update()
# Out:
# tensor(10.5185, grad_fn=<MeanBackward1>)
# tensor(0.4089, grad_fn=<MeanBackward1>)
# tensor(0.1549, grad_fn=<MeanBackward1>)
# tensor(0.1046, grad_fn=<MeanBackward1>)
# tensor(0.0946, grad_fn=<MeanBackward1>)
# tensor(0.0927, grad_fn=<MeanBackward1>)
# tensor(0.0923, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)
# tensor(0.0922, grad_fn=<MeanBackward1>)

# %%
plt.figure()
plt.scatter(x[:, 0], y, label='true');
plt.scatter(x[:, 0], x** 2 @ a, label='pred')
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib import animation, rc
rc('animation', html='jshtml', embed_limit=100)

# %%
a = nn.Parameter(tensor(1., 1))

fig = plt.figure()
plt.scatter(x[:, 0], y, c='green')
plt.plot(x[:, 0], x ** 2 @ a)
# plt.close()

# def animate(i):
#     update()
#     line.set_ydata(x ** 2 @ a)
#     return line,

# animation.FuncAnimation(fig, animate, np.arange(0, 200), interval=20)
# Out:
# <img src="data:image/png;base64,..." width="640">
